# %% [markdown]
# <h3>Notebook will be mainly used for the capstone project</h3>

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# <h3 style="font-family: verdana; font-size: 24px;color: #e39117;">Hello Capstone Project Course!</h3>
